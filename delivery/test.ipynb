# %%
import pandas as pd
import sqlite3

# %%
from functions.sql_functions import sql_connect
import logging

logger = logging.getLogger(__name__)
sql_con = sql_connect('orders', logger)

# %%
import datetime as dt

df = sql_con.get_all_orders()
# df = df[df['stage']=='accepted_deliverman']
# df['last_change'] = pd.to_datetime(df['last_change'])
# df['current_time'] = dt.datetime.now()
# df['time_delta'] = df['current_time'] - df['last_change']
# df['time_delta'] = df['time_delta'].apply(lambda x: x.seconds)
# df = df[df['time_delta'] > 10]
# records = df.to_dict('records')
# records
df.tail()
# Out:
#    track_num country address pass descriprion price  \
# 71    test54       q       w    e           r     t
# 72    test55       q       w    e           r     t
# 73    test56       q       w    e           r     t
# 74    test57       q       w    e           r     t
# 75    test58       q       w    e           r     t
#
#                                            path_image                stage  \
# 71  /home/ivan/Projects/git/Project/delivery/image...         in_warehouse
# 72  /home/ivan/Projects/git/Project/delivery/image...         in_warehouse
# 73  /home/ivan/Projects/git/Project/delivery/image...         in_warehouse
# 74  /home/ivan/Projects/git/Project/delivery/image...  accepted_deliverman
# 75  /home/ivan/Projects/git/Project/delivery/image...  accepted_deliverman
#
#                    last_change manager_id  ... warehouser_name  \
# 71  2023-08-20 03:12:06.998976  396022903  ...    Vanka Zhukov
# 72  2023-08-20 03:11:58.200594  396022903  ...    Vanka Zhukov
# 73  2023-08-20 03:13:48.156804  396022903  ...    Vanka Zhukov
# 74  2023-08-20 03:16:58.465400  396022903  ...    Vanka Zhukov
# 75  2023-08-20 03:16:11.799173  396022903  ...    Vanka Zhukov
#
#    warehouse_messageid delivery_group_messageid deliveryman_id  \
# 71                1573                     1679           None
# 72                1597                     None           None
# 73                1620                     1681           None
# 74                1643                     1683      396022903
# 75                1666                     1685      396022903
#
#    deliveryman_name delivery_private_messageid admin_group_messageid  \
# 71             None                       None                  1575
# 72             None                       None                  1599
# 73             None                       None                  1622
# 74     Vanka Zhukov                       1689                  1645
# 75     Vanka Zhukov                       1687                  1668
#
#    warehouse_mediaid delivery_group_mediaid delivery_private_mediaid
# 71              1572                   1678                     None
# 72              1596                   None                     None
# 73              1619                   1680                     None
# 74              1642                   1682                     1688
# 75              1665                   1684                     1686
#
# [5 rows x 22 columns]

# %%
con = sqlite3.connect(f'database/orders.db')
cur = con.cursor()
query = f"ALTER TABLE orders ADD COLUMN delivery_private_mediaid TEXT;"
cur.execute(query)

# %%
conn=sqlite3.connect('database/orders.db')
curs=conn.cursor()
curs.execute("DELETE  FROM orders WHERE track_num = 'teset88';")
conn.commit()
conn.close()

# %%
from inspect import getsourcefile
from os.path import abspath


abspath(getsourcefile(lambda:0))
# Out:
# '/tmp/ipykernel_586637/1586597091.py'
